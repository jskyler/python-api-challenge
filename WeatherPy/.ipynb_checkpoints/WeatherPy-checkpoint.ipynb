# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
#      |████████████████████████████████| 557 kB 2.2 MB/s eta 0:00:01
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559701 sha256=737a4d9e26a431806c8da1d22db2f580aa046586ad62c433f7dfb1c23893f8c9
#   Stored in directory: /Users/justine.skyler/Library/Caches/pip/wheels/6d/df/5e/ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

record = 0
set = 1

city_name = []
lat = []
long = []
max_temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []


print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    
    #Count of cities/sets of 50
    if record == 50:
        record = 0
        set += 1
    record += 1
    
    #Try validating each city
    try:
        #Pull weather info with successful attempts
        weather_response = requests.get(query_url+city).json()
        city_name.append(weather_response["name"])
        lat.append(weather_response["coord"]["lat"])
        long.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        humidity.append(weather_response["main"]["humidity"])
        clouds.append(weather_response["clouds"]["all"])
        wind_speed.append(weather_response["wind"]["speed"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        
        print(f"Processing Record {record} of Set {set} | {city}")
        
        
    except:
        #Print out for each city that can not be validated
        print("City not found. Skipping...")
        continue
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | grindavik
# City not found. Skipping...
# Processing Record 6 of Set 1 | tuatapere
# City not found. Skipping...
# Processing Record 8 of Set 1 | asuncion nochixtlan
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | hervey bay
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | tamandare
# Processing Record 14 of Set 1 | healdsburg
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | kuantan
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | belaya gora
# Processing Record 26 of Set 1 | varhaug
# Processing Record 27 of Set 1 | san quintin
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | minas novas
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | kalmunai
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 42 of Set 4 | bella union
# Processing Record 43 of Set 4 | parintins
# Processing Record 44 of Set 4 | bang saphan
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | acapulco
# Processing Record 47 of Set 4 | sokolo
# Processing Record 48 of Set 4 | svobodnyy
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | bambanglipuro
# Processing Record 1 of Set 5 | roebourne
# Processing Record 2 of Set 5 | crepy-en-valois
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | luena
# Processing Record 7 of Set 5 | muzhi
# City not found. Skipping...
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | talara
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | boromo
# Processing Record 14 of Set 5 | kutum
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | ancud
# Processing Record 18 of Set 5 | tual
# Processing Record 19 of Set 5 | faya
# Processing Record 20 of Set 5 | tuktoyaktuk
# Processing Record 21 of Set 5 | saint anthony
# Processing Record 22 of Set 5 | concordia
# Processing Record 23 of Set 5 | college
# Processing Record 24 of Set 5 | mirador
# Processing Record 25 of Set 5 | xiamen
# Processing Record 26 of Set 5 | altamont
# Processing Record 27 of Set 5 | labuhan
# Processing Record 28 of Set 5 | nicoya
# Processing Record 29 of Set 5 | pahrump
# Processing Record 30 of Set 5 | san vicente
# Processing Record 31 of Set 5 | bilibino
# Processing Record 32 of Set 5 | dzhebariki-khaya
# Processing Record 33 of Set 5 | apache junction
# Processing Record 34 of Set 5 | vostok
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | ranavav
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | samarai
# Processing Record 39 of Set 5 | santa maria
# Processing Record 40 of Set 5 | mana
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | nakatsu
# Processing Record 43 of Set 5 | ryotsu
# Processing Record 44 of Set 5 | deputatskiy
# Processing Record 45 of Set 5 | sioux lookout
# Processing Record 46 of Set 5 | saldanha
# Processing Record 47 of Set 5 | mendi
# Processing Record 48 of Set 5 | nenjiang
# Processing Record 49 of Set 5 | berlevag
# Processing Record 50 of Set 5 | mackay
# Processing Record 1 of Set 6 | quang ngai
# Processing Record 2 of Set 6 | saint-philippe
# Processing Record 3 of Set 6 | dongsheng
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | srednekolymsk
# Processing Record 6 of Set 6 | tayu
# Processing Record 7 of Set 6 | belmonte
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | poum
# Processing Record 10 of Set 6 | khorixas
# Processing Record 11 of Set 6 | kulautuva
# Processing Record 12 of Set 6 | mahon
# Processing Record 13 of Set 6 | hinton
# Processing Record 14 of Set 6 | whitecourt
# Processing Record 15 of Set 6 | batagay
# Processing Record 16 of Set 6 | chuy
# Processing Record 17 of Set 6 | lipany
# Processing Record 18 of Set 6 | peterhead
# Processing Record 19 of Set 6 | tura
# Processing Record 20 of Set 6 | mindelo
# Processing Record 21 of Set 6 | kyzyl-suu
# Processing Record 22 of Set 6 | rognan
# Processing Record 23 of Set 6 | ibra
# Processing Record 24 of Set 6 | conceicao do araguaia
# Processing Record 25 of Set 6 | fare
# Processing Record 26 of Set 6 | wukari
# City not found. Skipping...
# Processing Record 28 of Set 6 | kavieng
# Processing Record 29 of Set 6 | rocha
# Processing Record 30 of Set 6 | bayir
# Processing Record 31 of Set 6 | chibuto
# Processing Record 32 of Set 6 | majene
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | cherskiy
# Processing Record 35 of Set 6 | charyshskoye
# Processing Record 36 of Set 6 | boulsa
# Processing Record 37 of Set 6 | paita
# Processing Record 38 of Set 6 | buala
# Processing Record 39 of Set 6 | pangnirtung
# Processing Record 40 of Set 6 | puerto escondido
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | wenling
# Processing Record 43 of Set 6 | dikson
# Processing Record 44 of Set 6 | dingle
# City not found. Skipping...
# Processing Record 46 of Set 6 | lubango
# Processing Record 47 of Set 6 | olivenza
# Processing Record 48 of Set 6 | jumla
# Processing Record 49 of Set 6 | rosarito
# Processing Record 50 of Set 6 | amapa
# Processing Record 1 of Set 7 | bandarbeyla
# City not found. Skipping...
# Processing Record 3 of Set 7 | bengkulu
# Processing Record 4 of Set 7 | oyon
# Processing Record 5 of Set 7 | taldan
# Processing Record 6 of Set 7 | odienne
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | cabo san lucas
# Processing Record 9 of Set 7 | rawlins
# Processing Record 10 of Set 7 | eravur
# Processing Record 11 of Set 7 | berlin
# Processing Record 12 of Set 7 | sinnamary
# Processing Record 13 of Set 7 | adrar
# Processing Record 14 of Set 7 | hachinohe
# Processing Record 15 of Set 7 | pevek
# Processing Record 16 of Set 7 | nadym
# Processing Record 17 of Set 7 | ketchikan
# City not found. Skipping...
# Processing Record 19 of Set 7 | nishihara
# Processing Record 20 of Set 7 | broken hill
# Processing Record 21 of Set 7 | zharkent
# Processing Record 22 of Set 7 | ahuimanu
# Processing Record 23 of Set 7 | cheremshanka
# Processing Record 24 of Set 7 | ponta do sol
# Processing Record 25 of Set 7 | mikhaylovka
# Processing Record 26 of Set 7 | krasnoye
# Processing Record 27 of Set 7 | nago
# Processing Record 28 of Set 7 | tezu
# Processing Record 29 of Set 7 | vestmanna
# Processing Record 30 of Set 7 | san fernando
# Processing Record 31 of Set 7 | chingirlau
# Processing Record 32 of Set 7 | buraydah
# Processing Record 33 of Set 7 | verkhniy mamon
# Processing Record 34 of Set 7 | biak
# Processing Record 35 of Set 7 | leshukonskoye
# Processing Record 36 of Set 7 | hofn
# Processing Record 37 of Set 7 | sangar
# Processing Record 38 of Set 7 | tambilil
# Processing Record 39 of Set 7 | ginir
# Processing Record 40 of Set 7 | jiangyou
# Processing Record 41 of Set 7 | zenzeli
# Processing Record 42 of Set 7 | zinder
# Processing Record 22 of Set 9 | samagaltay
# Processing Record 23 of Set 9 | santa cruz
# Processing Record 24 of Set 9 | uyuni
# Processing Record 25 of Set 9 | sidi ali
# Processing Record 26 of Set 9 | guerrero negro
# Processing Record 27 of Set 9 | egvekinot
# Processing Record 28 of Set 9 | mangochi
# Processing Record 29 of Set 9 | praia
# Processing Record 30 of Set 9 | paraiso
# Processing Record 31 of Set 9 | nokaneng
# Processing Record 32 of Set 9 | kamloops
# Processing Record 33 of Set 9 | shuya
# Processing Record 34 of Set 9 | machado
# Processing Record 35 of Set 9 | samarinda
# City not found. Skipping...
# Processing Record 37 of Set 9 | naze
# Processing Record 38 of Set 9 | ponta grossa
# Processing Record 39 of Set 9 | atambua
# Processing Record 40 of Set 9 | puruaran
# Processing Record 41 of Set 9 | baykit
# Processing Record 42 of Set 9 | benguela
# Processing Record 43 of Set 9 | el dorado
# Processing Record 44 of Set 9 | cuiluan
# Processing Record 45 of Set 9 | shenjiamen
# Processing Record 46 of Set 9 | abu kamal
# Processing Record 47 of Set 9 | bull savanna
# Processing Record 48 of Set 9 | humaita
# Processing Record 49 of Set 9 | havre-saint-pierre
# Processing Record 50 of Set 9 | hammerfest
# Processing Record 1 of Set 10 | port-gentil
# Processing Record 2 of Set 10 | goure
# Processing Record 3 of Set 10 | itarema
# City not found. Skipping...
# Processing Record 5 of Set 10 | mehamn
# Processing Record 6 of Set 10 | asarganj
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | nome
# Processing Record 9 of Set 10 | mananara
# Processing Record 10 of Set 10 | asyut
# Processing Record 11 of Set 10 | ngunguru
# Processing Record 12 of Set 10 | okha
# City not found. Skipping...
# Processing Record 14 of Set 10 | tangjiazhuang
# Processing Record 15 of Set 10 | coquimbo
# Processing Record 16 of Set 10 | anadyr
# Processing Record 17 of Set 10 | nha trang
# Processing Record 18 of Set 10 | ossora
# Processing Record 19 of Set 10 | ust-karsk
# Processing Record 20 of Set 10 | terdal
# Processing Record 21 of Set 10 | havelock
# Processing Record 22 of Set 10 | fort nelson
# Processing Record 23 of Set 10 | marivan
# Processing Record 24 of Set 10 | faanui
# City not found. Skipping...
# Processing Record 26 of Set 10 | teya
# Processing Record 27 of Set 10 | wells
# Processing Record 28 of Set 10 | colac
# Processing Record 29 of Set 10 | taman
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | newport
# Processing Record 32 of Set 10 | saiki
# Processing Record 33 of Set 10 | rawson
# Processing Record 34 of Set 10 | evensk
# Processing Record 35 of Set 10 | alice springs
# Processing Record 36 of Set 10 | yining
# Processing Record 37 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 10 | naron
# Processing Record 39 of Set 10 | alugan
# Processing Record 40 of Set 10 | lata
# Processing Record 41 of Set 10 | santa cruz cabralia
# Processing Record 42 of Set 10 | bonthe
# Processing Record 43 of Set 10 | noumea
# City not found. Skipping...
# Processing Record 45 of Set 10 | harper
# Processing Record 46 of Set 10 | ballina
# Processing Record 47 of Set 10 | cayenne
# Processing Record 48 of Set 10 | tomigusuku
# Processing Record 49 of Set 10 | yar-sale
# Processing Record 50 of Set 10 | tessalit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 11 | centralia
# Processing Record 4 of Set 11 | vitim
# Processing Record 5 of Set 11 | domoni
# Processing Record 6 of Set 11 | aklavik
# Processing Record 7 of Set 11 | songjianghe
# City not found. Skipping...
# Processing Record 9 of Set 11 | saline
# Processing Record 10 of Set 11 | vardo
# Processing Record 11 of Set 11 | concarneau
# City not found. Skipping...
# Processing Record 13 of Set 11 | kpandae
# Processing Record 14 of Set 11 | mugur-aksy
# Processing Record 15 of Set 11 | beeville
# Processing Record 16 of Set 11 | ortakoy
# Processing Record 17 of Set 11 | itabirito
# Processing Record 18 of Set 11 | manaure
# City not found. Skipping...
# Processing Record 20 of Set 11 | at-bashi
# Processing Record 21 of Set 11 | karratha
# Processing Record 22 of Set 11 | zyryanka
# Processing Record 23 of Set 11 | madang
# Processing Record 24 of Set 11 | zavetnoye
# Processing Record 25 of Set 11 | indiana
# Processing Record 26 of Set 11 | pacific grove
# Processing Record 27 of Set 11 | puerto colombia
# Processing Record 28 of Set 11 | serenje
# Processing Record 29 of Set 11 | tipitapa
# City not found. Skipping...
# Processing Record 31 of Set 11 | aksu
# Processing Record 32 of Set 11 | mahanoro
# Processing Record 33 of Set 11 | santander
# Processing Record 34 of Set 11 | luderitz
# City not found. Skipping...
# Processing Record 36 of Set 11 | bonfim
# City not found. Skipping...
# Processing Record 38 of Set 11 | churapcha
# Processing Record 39 of Set 11 | archidona
# City not found. Skipping...
# Processing Record 41 of Set 11 | coleraine
# Processing Record 42 of Set 11 | great falls
# Processing Record 43 of Set 11 | zhaoqing
# Processing Record 44 of Set 11 | clyde river
# Processing Record 45 of Set 11 | burnie
# Processing Record 46 of Set 11 | bay roberts
# Processing Record 47 of Set 11 | auchi
# Processing Record 48 of Set 11 | krasnoselkup
# Processing Record 49 of Set 11 | namanga
# Processing Record 50 of Set 11 | fairbanks
# Processing Record 1 of Set 12 | saint-augustin
# City not found. Skipping...
# Processing Record 3 of Set 12 | viytivka
# Processing Record 4 of Set 12 | kuching
# Processing Record 5 of Set 12 | champerico
# Processing Record 6 of Set 12 | sur
# City not found. Skipping...
# Processing Record 8 of Set 12 | guntakal
# Processing Record 9 of Set 12 | atagay
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | teknaf
# Processing Record 12 of Set 12 | khudumelapye
# Processing Record 13 of Set 12 | riyadh
# Processing Record 14 of Set 12 | araouane
# Processing Record 15 of Set 12 | ryazhsk
# Processing Record 16 of Set 12 | moose factory
# Processing Record 17 of Set 12 | athabasca
# Processing Record 18 of Set 12 | tornio
# Processing Record 19 of Set 12 | kununurra
# Processing Record 20 of Set 12 | luwingu
# Processing Record 21 of Set 12 | chiang khong
# Processing Record 22 of Set 12 | soyo
# Processing Record 23 of Set 12 | chaihe
# Processing Record 24 of Set 12 | orlik
# Processing Record 25 of Set 12 | staunton
# Processing Record 26 of Set 12 | la palma
# Processing Record 27 of Set 12 | neuquen
# Processing Record 28 of Set 12 | mayo
# Processing Record 29 of Set 12 | tongchuan
# City not found. Skipping...
# Processing Record 31 of Set 12 | mareeba
# Processing Record 32 of Set 12 | haapiti
# Processing Record 33 of Set 12 | kashary
# Processing Record 34 of Set 12 | sao sebastiao do paraiso
# Processing Record 35 of Set 12 | inhambane
# Processing Record 36 of Set 12 | latacunga
# Processing Record 37 of Set 12 | san juan
# Processing Record 38 of Set 12 | kita
# Processing Record 39 of Set 12 | szentgotthard
# Processing Record 40 of Set 12 | morgan city
# Processing Record 41 of Set 12 | agadez
# Processing Record 42 of Set 12 | guatire
# Processing Record 43 of Set 12 | guilin
# Processing Record 44 of Set 12 | lavrentiya
# Processing Record 45 of Set 12 | hemsedal
# Processing Record 46 of Set 12 | marblehead
# Processing Record 47 of Set 12 | marrakesh
# Processing Record 48 of Set 12 | alleroy
# Processing Record 49 of Set 12 | bathsheba
# Processing Record 50 of Set 12 | tautira
# Processing Record 1 of Set 13 | maragogi
# Processing Record 2 of Set 13 | bad freienwalde
# Processing Record 3 of Set 13 | kyshtovka

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Put data into dictionary
wx_dict = {'City':city_name,
          'Lat':lat,
          'Lng':long,
          'Max Temp':max_temp,
          'Humidity':humidity,
          'Cloudiness':clouds,
          'Wind Speed':wind_speed,
          'Country':country,
          'Date':date}

#Put dictionary into DataFrame
wx_summary = pd.DataFrame(wx_dict)

#Print DataFrame into a csv
wx_summary.to_csv(output_data_file)

#Print DataFrame here
wx_summary
# Out:
#                     City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                   Hilo  19.73 -155.09     69.80        77           1
# 1                Ushuaia -54.80  -68.30     39.20        69          75
# 2              Grindavik  63.84  -22.43     33.80        80          40
# 3              Tuatapere -46.13  167.68     56.79        84         100
# 4    Asunción Nochixtlán  17.47  -97.23     69.17        38           0
# ..                   ...    ...     ...       ...       ...         ...
# 550            Bathsheba  13.22  -59.52     87.80        70          20
# 551              Tautira -17.73 -149.15     80.60        78          40
# 552             Maragogi  -9.01  -35.22     82.09        71          16
# 553      Bad Freienwalde  52.79   14.03     52.00        83          99
# 554            Kyshtovka  56.55   76.63     21.40        97          94
#
#      Wind Speed Country        Date
# 0          8.05      US  1605376789
# 1         20.80      AR  1605376789
# 2         12.75      IS  1605376789
# 3          5.73      NZ  1605376789
# 4          5.75      MX  1605376790
# ..          ...     ...         ...
# 550       11.41      BB  1605376921
# 551        6.93      PF  1605376922
# 552       10.60      BR  1605376922
# 553        6.76      DE  1605376922
# 554        5.39      RU  1605376922
#
# [555 rows x 9 columns]

# %%
#Perform quick analysis of data in DataFrame
wx_analysis = pd.DataFrame(wx_summary.describe())

#Print quick analysis
wx_analysis
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  555.000000  555.000000  555.000000  555.000000  555.000000  555.000000
# mean    19.625081   16.863964   58.114865   71.533333   49.028829    8.167766
# std     32.822008   91.927776   26.290762   20.814642   38.306515    5.902458
# min    -54.800000 -179.170000  -24.290000   13.000000    0.000000    0.250000
# 25%     -8.045000  -61.155000   40.425000   60.000000    6.000000    3.835000
# 50%     21.680000   18.420000   66.000000   77.000000   43.000000    6.710000
# 75%     47.225000  102.020000   78.880000   87.500000   90.000000   11.230000
# max     78.220000  178.420000  101.230000  100.000000  100.000000   38.030000
#
#                Date
# count  5.550000e+02
# mean   1.605377e+09
# std    6.714267e+01
# min    1.605377e+09
# 25%    1.605377e+09
# 50%    1.605377e+09
# 75%    1.605377e+09
# max    1.605377e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Outline Scatter Plot data
plt.scatter(wx_summary["Lat"],wx_summary["Max Temp"])

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature")
plt.grid(True)

#Save Scatter Plot
plt.savefig("output_data/Latitude vs. Temperature Plot.png")

#Print Scatter Plot
plt.show()

#The plot shows that temperatures are warmer the closer they are to the equator and colder at further latitudes

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Outline Scatter Plot data
plt.scatter(wx_summary["Lat"],wx_summary["Humidity"])

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")
plt.grid(True)

#Save Scatter Plot
plt.savefig("output_data/Latitude vs. Humidity Plot.png")

#Print Scatter Plot
plt.show()

#The plot appears to show that cities at latitudes further from the equator have a higher percentage of humidity 
#and almost no low percentages of humidity in the same areas

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Outline Scatter Plot data
plt.scatter(wx_summary["Lat"],wx_summary["Cloudiness"])

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid(True)

#Save Scatter Plot
plt.savefig("output_data/Latitude vs. Cloudiness Plot.png")

#Print Scatter Plot
plt.show()

#The plot appears to show that there is some higher percentages of cloudiness further from the equator

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Outline Scatter Plot data
plt.scatter(wx_summary["Lat"],wx_summary["Wind Speed"])

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed")
plt.grid(True)

#Save Scatter Plot
plt.savefig("output_data/Latitude vs. Wind Speed Plot.png")

#Print Scatter Plot
plt.show()

#The plot appears to show there is very little correlation between windspeed and latitude

# %% [markdown]
# ## Linear Regression

# %%
#Outline data in northern and southern hemisphere
northern_hem = wx_summary.loc[wx_summary["Lat"] > 0]
southern_hem = wx_summary.loc[wx_summary["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(northern_hem["Lat"],northern_hem["Max Temp"])
regress_values = northern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline graph
plt.scatter(northern_hem["Lat"],northern_hem["Max Temp"])
plt.plot(northern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(5,-15),fontsize=15,color="red")

#Label and detail graph
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Northern Hemisphere - City Latitude vs. Max Temp")

#Save Scatter Plot
plt.savefig("output_data/Northern Hemisphere - Max Temp vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#The plot shows there is a direct correlation between high max temps and lower latitudes as well as low max temps
# and higher latitudes
# Out:
# The r-value is: 0.7768014140143384

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(southern_hem["Lat"],southern_hem["Max Temp"])
regress_values = southern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline graph
plt.scatter(southern_hem["Lat"],southern_hem["Max Temp"])
plt.plot(southern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")

#Label and detail graph
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Southern Hemisphere - City Latitude vs. Max Temp")

#Save Scatter Plot
plt.savefig("output_data/Southern Hemisphere - Max Temp vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#The plot shows there is a correlation between medium to high max temps and latitudes closer to the equator 
#as well as low max temps and further away from the equator
# Out:
# The r-value is: 0.4382936248807643

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(northern_hem["Lat"],northern_hem["Humidity"])
regress_values = northern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline and detail graph
plt.scatter(northern_hem["Lat"],northern_hem["Humidity"])
plt.plot(northern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - City Latitude vs. Humidity")

#Save Scatter Plot
plt.savefig("output_data/Northern Hemisphere - Humidity (%) vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#This plot appears to show that humidity is becomes reliably higher at latitudes further from the equator and lower
#humidities are essentially non-existent
# Out:
# The r-value is: 0.1924969711067802

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(southern_hem["Lat"],southern_hem["Humidity"])
regress_values = southern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline and detail graph
plt.scatter(southern_hem["Lat"],southern_hem["Humidity"])
plt.plot(southern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - City Latitude vs. Humidity")

#Save Scatter Plot
plt.savefig("output_data/Southern Hemisphere - Humidity (%) vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#This plot appears to show there is a very very slight correlation between the rise in humidity as the latitudes 
#approach the equator
# Out:
# The r-value is: 0.0006861604605329161

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(northern_hem["Lat"],northern_hem["Cloudiness"])
regress_values = northern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline and detail graph
plt.scatter(northern_hem["Lat"],northern_hem["Cloudiness"])
plt.plot(northern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(45,25),fontsize=15,color="red")

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - City Latitude vs. Cloudiness")

#Save Scatter Plot
plt.savefig("output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#This plot appears to show there is a correlation between low percentages of cloudiness at lower latitudes and higher
#percentages of cloudiness at higher latitudes
# Out:
# The r-value is: 0.0877799549650573

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(southern_hem["Lat"],southern_hem["Cloudiness"])
regress_values = southern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline and detail graph
plt.scatter(southern_hem["Lat"],southern_hem["Cloudiness"])
plt.plot(southern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - City Latitude vs. Cloudiness")

#Save Scatter Plot
plt.savefig("output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#This plot appears to show there is a very slight correlation between the rise in cloudiness as the latitudes 
#approach the equator
# Out:
# The r-value is: 0.004511191022500638

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(northern_hem["Lat"],northern_hem["Wind Speed"])
regress_values = northern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline and detail graph
plt.scatter(northern_hem["Lat"],northern_hem["Wind Speed"])
plt.plot(northern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(10,30),fontsize=15,color="red")

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - City Latitude vs. Wind Speed")

#Save Scatter Plot
plt.savefig("output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#This plot appears to show that wind speeds increases slightly from the equator to higher latitudes but is overall rather low
# Out:
# The r-value is: 0.02085230112658438

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create equation
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(southern_hem["Lat"],southern_hem["Wind Speed"])
regress_values = southern_hem["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Outline and detail graph
plt.scatter(southern_hem["Lat"],southern_hem["Wind Speed"])
plt.plot(southern_hem["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")

#Label graph
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - City Latitude vs. Wind Speed")

#Save Scatter Plot
plt.savefig("output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude.png")

#Print Scatter Plot
plt.show()

#Print R-Value
print(f"The r-value is: {rvalue**2}")

#This plot appears to show that wind speed reduces as it approaches the equator from lower latitudes
# Out:
# The r-value is: 0.028957821715833033
